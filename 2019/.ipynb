# %% [markdown]
# ## Latihan Soal
#
# ### 1. Menghitung Luas Lingkaran
#
# Dalam ilmu matematika, luas dan keliling lingkaran dihitung menggunakan rumus berikut :
#
# L = pi.r^2
# K = 2.pi.r
#
# (ambil pi dari module math)
#
# Dalam kasus ini, kita memerlukan satu variabel input yaitu nilai jari-jari (r)
#
# ### 2. Mengonversi Suhu dari Farenheit ke Celcius
#
# Buatlah program untuk melakukan konversi suhu dari Farenheit ke Celcius.Rumus yang digunakan adalah :
#
# C= 5 x (F-32) /9
#
# Masukan dari program inii adalah suhu dalam Farenheit (F)
#
# ### 3. Menghitung volume dan Luas permukaan balok
#
# Buatlah program untuk menghitung volume dan luas permukaan balok dengan menggunakan rumus berikut :
#
# V = p.l.t
# LP = 2(p.l+p.t+l.t)
#
# Untuk program ini, kita memerlukan tiga input yaitu p (panjang), l(lebar, dan t(tinggi)
#
# ### 4. Menukar nilai dari dua variabel
#
# Pada kasus-kasus tertentu dalam pemrograman, ada kalanya kita perlu menukar isi atau nilai dari dua variabel. Sebagai contoh, kita ingin menukar nilai dari variable a dan b. Hasil penukarang yang diinginkan adalah variable a menjadi variable b, dan sebaliknya, variable b menjadi variabel a.
#
# ### 5. Mengkonversi Jam (hh:mm:ss) ke detik
#
# Pada kasus ini, kita akan membuat kode program yang berfungsi untuk mengkonversi durasi waktu dari format jam (hh:mm:SS) ke detik.
#
# total detik = (jam*3600) + (menit*60) + detik
#
# Pada kode ini, dibutuhkan 3 variabel masukan, yaitu jam, menit dan detik.
#
# ### 6. Menentukan nilai maksimum dari Tiga bilangan
#
# Pada kasus ini, kita akan membuat kode program yang dapat menentukan nilai terbesar dari dua buah bilangan yang dimasukka user melalui keyboard.
#
# ### 7. Menentukan akar-akar persamaan kuadrat
#
# Bentuk umum dari akar persamaan kuadrat adalah  :
#
# ax^2 + bx + c =0
#
# Dengan a, b, dan c adalah koefisien persamaan. Kita akan menghitung akar-akar persamaan dengan rumus berikut :
#
# ![akar%20persamaan%20kuadrat.JPG](attachment:akar%20persamaan%20kuadrat.JPG)
#
# Jenis-jenis akar akan bergantung pada nilai diskriminan (D), dimana D= b^2 - 4ac
#
#  - Jika D>0 maka akar-akarnya riil dan berbeda
#  - Jika D=0 maka akar-akarnya riil dan sama
#  - Jika D<0 maka akar-akarnya imajiner
#
# ### 8. Menentukan Nilai Indeks Ujia
#
# Sebuah perguruan tinggi XYZ menghitung nilai akhir ujian para mahasiswanya dengan ketentuan sebagai berikut :
#
# Nilai akhir (NA) = 65% Nilai UAS + 35% Nilai UTS
#
# Selanjutnya penentuan Nilai Indeks dilakukan menggunakan aturan berikut :
#
#  - Jika NA >= 80, maka Nilai Indeks = A
#  - Jika 80> NA >= 70 maka Nilai Indeks = B
#  - Jika 70 > NA >= 55 maka Nilai Indeks = C
#  - Jika 55 > NA >= 40 maka Nilai Indeks = D
#  - Jika NA < 40 maka Nilai Indeks = E
#
# ### 9. Menghitung Nilai Rata-Rata Bilangan
#
# Buatlah sebuah program yang dapat menghitung nilai rata-rata dari kelompok bilangan tertentu. Bilangan tersebut merupakan bilangan yang dimasukkan oleh user melalu keyboard.Untuk menyelesaikan kasus seperti ini diperlukan tipe data list untuk menampung semua data yang dimasukkan oleh user. Selain itu juga, kita perlu menggunakan perulangan untuk mempermudah proses input serta pengaksesan data.
#
# ### 10. Menghitung Nilai Faktorial
#
# Suatu bilangan bulat positif (misal : 5) dapat dihitung faktorialnya menggunakan cara berikut :
#
# 5!= 5 x 4 x 3 x 2 x 1
#
# Hal yang perlu anda ketahui adalah 0! akan bernilai 1.

# %% [markdown]
# ## JAWABAN

# %%
#9

#menyiapka list untuk menampung data
data =[]

#meminta user memasukkan banyak data
n = int(input("\nMasukkan banyak data : "))
print() # membuat spasi baris

jumlah = 0

for i in range(0,n):
    #meminta user mengisi data bilangan
    temp = int(input("Masukkan data ke-%d: " % (i+1)))
    #menambahkan data kedalam list
    data.append(temp)
    #menghitung jumlah total bilangan
    jumlah += data(i)

#menghitung rata-rata
    rata2 = jumlah/n4
    print ("\n Rata-rata = %0.2f" % rata2)
# Out:
# Masukkan banyak data : 3
#
# Masukkan data ke-1: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-63cc0d2ffbe8> in <module>
#      16     data.append(temp)
#      17     #menghitung jumlah total bilangan
# ---> 18     jumlah += data(i)
#      19
#      20 #menghitung rata-rata
#
# TypeError: 'list' object is not callable

# %%
# 10

#memasukkan input 
n = int(input("Masukkan Bilangan :"))

#bilangan harus bulat positif 
if n < 0 :
    print("\nBilangan tidak boleh negatif")

#nilai inisial
faktorial =1

#menghitung faktorial
print("%d! = "% n, end='')
i = n 
while i >= 1:
    if i!= 1:
        print ("%d x" % i, end='')
    else : 
        print("%d =" % i, end='')
    faktorial *= i;
    i -= 1;
print (faktorial)
# Out:
# Masukkan Bilangan :5
# 5! = 5 x4 x3 x2 x1 =120
