# %%
var = 1
print (var > 0)
print (not (var<=0))

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %%
i=15
j=22
k=format(i,"b")
l="{0:b}".format(j)
m = k and l
n = i & j
log= i and j
print("m= ",m)
print("n= ",n)
print ("o=",o)
# Out:
# m=  10110
# n=  6
# o= 22

# %%
print(k)
# Out:
# 1111

# %%
l="{0:b}".format(j)
print(l)
# Out:
# 10110

# %%
print(i and j)
# Out:
# 22

# %%
lognet= not i
print (lognet)
bitneg = ~i
print (bitneg)
# Out:
# False
# -16

# %%
flagRegister= 0x1234
theMask=8

print (format(flagRegister,"b"))
print (format(theMask,"b"))

flagRegister = flagRegister | theMask

flagRegister |= theMask
print (format(flagRegister,"b"))
print (format(theMask,"b"))
# Out:
# 1001000110100
# 1000
# 1001000111100
# 1000

# %%
var = 17
geserkanan = var >> 1
geserkiri = var << 2
print(var, geserkanan, geserkiri)
print(format(17,"b"))
print(format(8,"b"))
print(format(68,"b"))
# Out:
# 17 8 68
# 10001
# 1000
# 1000100

# %%
x = 4
y = 1

a = x & y
b = x | y
c = ~x
d = x ^ 5
e = x >> 2
f = x << 2

print(a, b, c, d, e, f)
# Out:
# 0 5 -5 1 1 16
