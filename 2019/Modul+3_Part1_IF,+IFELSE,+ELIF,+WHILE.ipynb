# %% [markdown]
# # Modul 3 Python Essentials
# ### Modul 3_Part1_IF, IFELSE, ELIF, WHILE
#
# In this module, you will learn about:
#
# Boolean values;
# if-elif-else instructions;
# the while and for loops;
# flow control;
# logical and bitwise operations;
# lists and arrays.

# %% [markdown]
# #### 1. EQUALITY: the equal to operator (==)

# %%
#TRUE FALSE
2==2
# Out:
# False

# %%
2==2.0
# Out:
# True

# %%
2==2.
# Out:
# True

# %%
1==2
# Out:
# False

# %%
var = 0 # assigning 0 to var
print(var == 0)

var = 1 # assigning 1 to var
print(var == 0)
# Out:
# True
# False

# %% [markdown]
# #### 2. Inequality: the not equal to operator (!=)

# %%
var = 0 # assigning 0 to var
print(var != 0)

var = 1 # assigning 1 to var
print(var != 0)
# Out:
# False
# True

# %% [markdown]
# #### 3. Comparison operators: greater than  (>)
# #### 4. Comparison operators: greater than or equal to (>=)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# LAB
#
# Estimated time
# 5 minutes
#
# Level of difficulty
# Very Easy
#
# Objectives
# becoming familiar with the the input() function;
# becoming familiar with comparison operators in Python.
# Scenario
# Using one of the comparison operators in Python, write a simple two-line program that takes the parameter n as input, which is an integer, and prints  False if n is less than 100, and True if n is greater than or equal to 100.
#
# Don't create any if blocks (we're going to talk about them very soon). Test your code using the data we've provided for you.
#
# Test Data
#
# Sample input: 55
#
# Expected output: False
#
# Sample input: 99
#
# Expected output: False
#
# Sample input: 100
#
# Expected output: True
#
# Sample input: 101
#
# Expected output: True
#
# Sample input: -5
#
# Expected output: False
#
# Sample input: +123
#
# Expected output: True

# %% [markdown]
# #### 5. Conditions and conditional
#
# if true_or_not: <br>
#    <t> do_this_if_true

# %% [raw]
# In real life, we often express a desire:
#
# if the weather is good, we'll go for a walk
#
# then, we'll have lunch

# %%
#IF statement

if theWeatherIsGood:
    goForAWalk()
haveLunch()

# %%
#IF-ELSE statement:

if theWeatherIsGood:
    goForAWalk()
else:
    goToATheater()
haveLunch()

# %%
#ELIF statement:
if theWeatherIsGood:
    goForAWalk()
elif ticketsAreAvailable:
    goToTheTheater()
elif tableIsAvailable:
    goForLunch()
else:
    playChessAtHome()

# %% [markdown]
# #### 6. Pseudocode and introduction to loops

# %% [raw]
# line 01 largestNumber = -999999999
# line 02 number = int(input())
# line 03 if number == -1:
# line 04     print(largestNumber)
# line 05     exit()
# line 06 if number > largestNumber:
# line 07     largestNumber = number
# line 08 go to line 02

# %%
#to find the largest number of all, you can use a Python built-in function called max()

#CONTOH

# read three numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
number3 = int(input("Enter the third number: "))

# check which one of the numbers is the greatest
# and pass it to the largestNumber variable

largestNumber = max(number1, number2, number3)

# print the result
print("The largest number is:", largestNumber)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Exercise 1

#What is the output of the following snippet?

x = 5
y = 10
z = 8

print(x > y)
print(y > z)
# Out:
# False
# True

# %%
#Exercise 2

#What is the output of the following snippet?

x, y, z = 5, 10, 8

print(x > z)
print((y - 5) == x)
# Out:
# False
# True

# %%
#Exercise 3

#What is the output of the following snippet?

x, y, z = 5, 10, 8
x, y, z = z, y, x

print(x > z)
print((y - 5) == x)
# Out:
# True
# False

# %%
#Exercise 4

#What is the output of the following snippet?

x = 10

if x == 10:
    print(x == 10)
if x > 5:
    print(x > 5)
if x < 10:
    print(x < 10)
else:
    print("else")
# Out:
# True
# True
# else

# %%
#Exercise 5

#What is the output of the following snippet?

x = "1"

if x == 1:
    print("one")
elif x == "1":
    if int(x) > 1:
        print("two")
    elif int(x) < 1:
        print("three")
    else:
        print("four")
if int(x) == 1:
    print("five")
else:
    print("six")
# Out:
# four
# five

# %%
#Exercise 6

#What is the output of the following snippet?

x = 1
y = 1.0
z = "1"

if x == y:   #1==1.0 ADALAH TRUE
    print("one")
if y == int(z):
    print("two")
elif x == y:
    print("three")
else:
    print("four")
# Out:
# one
# two

# %% [raw]
# WHILE STATEMENT
#
# while there is something to do
#     do it
#
# while conditional_expression:
#     instruction
#
#
# If you notice some similarities to the if instruction, that's quite all right.
# Indeed, the syntactic difference is only one: you use the word while instead of the word if.
#
# The semantic difference is more important: when the condition is met,
# if performs its statements only once; while repeats the execution as long as the condition evaluates to True.

# %%
while conditional_expression:
    instruction_one
    instruction_two
    instruction_three
    :
    :
    instruction_n
